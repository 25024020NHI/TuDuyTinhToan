# %% [markdown]
# ### Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
a,b= map(float,input().split())
print("dien tich", a*b ,"chu vi",2*(a+ b))
# Out:
# dien tich 3.0 chu vi 8.0

# %% [markdown]
# ### Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r=float(input())
print("dien tich", r*r*3.14, "chu vi", 2*3.14*r)
# Out:
# dien tich 50.24 chu vi 25.12

# %% [markdown]
# ### Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
a,b,c= map(float,input().split())
if a+c>b and a+b>c and b+c>a:
    d=(a+b+c)/2
    s= ((d-a)*(d-b)*(d-c)*d)**0.5
    if a==b==c:
        print("tam giac deu", "Chu vi:", 2*d, "Dien tich:", s)
    elif a==b or a==c or b==c:
        print("tam giac can", "Chu vi:", 2*d, "Dien tich:", s)
    elif 2*s==a*b or 2*s==a*c or 2*s==b*c:
        print("tam giac vuong", "Chu vi:", 2*d, "Dien tich:", s)
    else:
        print("tam giac thuong", "Chu vi:", 2*d, "Dien tich:", s)
else:
    print("khong la ba canh cua mot tam giac")
# Out:
# tam giac deu Chu vi: 9.0 Dien tich: 3.897114317029974

# %% [markdown]
# ### Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b = map(float,input().split())
print("nghiem la:", -b/a)
# Out:
# nghiem la: -2.0

# %% [markdown]
# ### Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c= map(float,input().split())
dental= b*b-4*a*c
if dental<0:
    print("phuong trinh vo nghiem")
elif dental==0:
    print("phuong trinh co nghiem kep:", -b/(2*a))
else:
    x1=(-b-dental**0.5)/(2*a)
    x2=(-b+dental**0.5)/(2*a)
    print("phuong trinh co 2 nghiem la:", x1, x2)
# Out:
# phuong trinh vo nghiem

# %% [markdown]
# ### Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím)

# %%
a,b,c,d = map(int,input().split())
m= max(a,b,c,d)
print(m)
# Out:
# 4

# %% [markdown]
# ### Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d = map(int,input().split())
m= min(a,b,c,d)
print(m)
# Out:
# 1

# %% [markdown]
# ### Bài 8: Giải hệ phương trình tuyến tính: ax + by = m va cx + dy = n

# %%
a,b,c,d,m,n= map(int,input().split())
print("x=", (m*d-n*b)/(a*d-b*c), "y=", (m*c-n*a)/(b*c-d*a))
# Out:
# x= 1.0 y= 1.0

# %% [markdown]
# ### Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây

# %%
s= int(input())
m= s/60
h=int(m)/60
print(int(h), 'gio',int(m)%60, "phut", s%60, "giay" )
# Out:
# 1 gio 0 phut 1 giay

# %% [markdown]
# ### Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a,b,r=map(int,input().split())
x,y=map(int,input().split())
if ((x-a)**2+(y-b)**2)**0.5 != r:
    print('A khong thuoc duong tron')
else:
    print('A co thuoc duong tron')
# Out:
# A khong thuoc duong tron

# %% [markdown]
# ### Bài 11: Tính x mu y (Với x, y là số thực)

# %%
x,y= map(int,input().split())
print(x ,"mu", y ,"=", x**y)
# Out:
# 2 mu 3 = 8
